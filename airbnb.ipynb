# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# %matplotlib inline

# %%
seattle_listings = pd.read_csv('http://data.insideairbnb.com/united-states/wa/seattle/2016-01-04/visualisations/listings.csv')

# %%
seattle_listings.head()
# Out:
#         id                                 name   host_id host_name  \
# 0   241032         Stylish Queen Anne Apartment    956883       NaN
# 1   953595   Bright & Airy Queen Anne Apartment   5177328    Andrea
# 2  3308979  New Modern House-Amazing water view  16708587       NaN
# 3  7421966                   Queen Anne Chateau   9851441       NaN
# 4   278830       Charming craftsman 3 bdm house   1452570       NaN
#
#   neighbourhood_group    neighbourhood   latitude   longitude  \
# 0          Queen Anne  West Queen Anne  47.636289 -122.371025
# 1          Queen Anne  West Queen Anne  47.639123 -122.365666
# 2          Queen Anne  West Queen Anne  47.629724 -122.369483
# 3          Queen Anne  West Queen Anne  47.638473 -122.369279
# 4          Queen Anne  West Queen Anne  47.632918 -122.372471
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     85               1                207  2016-01-02
# ...

# %%
seattle_listings.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  3.818000e+03  3.818000e+03  3818.000000  3818.000000  3818.000000
# mean   5.550111e+06  1.578556e+07    47.628961  -122.333103   127.976166
# std    2.962660e+06  1.458382e+07     0.043052     0.031745    90.250022
# min    3.335000e+03  4.193000e+03    47.505088  -122.417219    20.000000
# 25%    3.258256e+06  3.275204e+06    47.609418  -122.354320    75.000000
# 50%    6.118244e+06  1.055814e+07    47.623601  -122.328874   100.000000
# 75%    8.035127e+06  2.590309e+07    47.662694  -122.310800   150.000000
# max    1.034016e+07  5.320861e+07    47.733358  -122.240607  1000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     3818.000000        3818.000000        3191.000000
# mean         2.369303          22.223415           2.078919
# std         16.305902          37.730892           1.822348
# min          1.000000           0.000000           0.020000
# ...

# %%
seattle_reviews=pd.read_csv('http://data.insideairbnb.com/united-states/wa/seattle/2016-01-04/visualisations/reviews.csv')

# %%
seattle_reviews.head()
# Out:
#    listing_id        date
# 0     7202016  2015-07-19
# 1     7202016  2015-07-20
# 2     7202016  2015-07-26
# 3     7202016  2015-08-02
# 4     7202016  2015-08-10

# %%
neighborhood_plot = seattle_listings['neighbourhood_group'].hist(bins=20)

# %%
sns.pairplot(seattle_listings.loc[:,['price','neighbourhood_group','neighbourhood','latitude','longitude','calculated_host_listings_count','availability_365']].dropna())

# %%
seattle_dummy = pd.get_dummies(seattle_listings, columns=['neighbourhood_group'])

# %%
seattle_dummy.head()
# Out:
#         id                                 name   host_id host_name  \
# 0   241032         Stylish Queen Anne Apartment    956883       NaN
# 1   953595   Bright & Airy Queen Anne Apartment   5177328    Andrea
# 2  3308979  New Modern House-Amazing water view  16708587       NaN
# 3  7421966                   Queen Anne Chateau   9851441       NaN
# 4   278830       Charming craftsman 3 bdm house   1452570       NaN
#
#      neighbourhood   latitude   longitude        room_type  price  \
# 0  West Queen Anne  47.636289 -122.371025  Entire home/apt     85
# 1  West Queen Anne  47.639123 -122.365666  Entire home/apt    150
# 2  West Queen Anne  47.629724 -122.369483  Entire home/apt    975
# 3  West Queen Anne  47.638473 -122.369279  Entire home/apt    100
# 4  West Queen Anne  47.632918 -122.372471  Entire home/apt    450
#
#    minimum_nights                ...                 \
# 0               1                ...
# 1               2                ...
# ...

# %%
seattle_listings['neighbourhood_group'].unique()
# Out:
# array(['Queen Anne', 'Ballard', 'Other neighborhoods', 'Cascade',
#        'Central Area', 'University District', 'Downtown', 'Magnolia',
#        'West Seattle', 'Interbay', 'Beacon Hill', 'Rainier Valley',
#        'Delridge', 'Seward Park', 'Northgate', 'Capitol Hill', 'Lake City'], dtype=object)

# %%
seattle_listings.head()
# Out:
#         id                                 name   host_id host_name  \
# 0   241032         Stylish Queen Anne Apartment    956883       NaN
# 1   953595   Bright & Airy Queen Anne Apartment   5177328    Andrea
# 2  3308979  New Modern House-Amazing water view  16708587       NaN
# 3  7421966                   Queen Anne Chateau   9851441       NaN
# 4   278830       Charming craftsman 3 bdm house   1452570       NaN
#
#   neighbourhood_group    neighbourhood   latitude   longitude  \
# 0          Queen Anne  West Queen Anne  47.636289 -122.371025
# 1          Queen Anne  West Queen Anne  47.639123 -122.365666
# 2          Queen Anne  West Queen Anne  47.629724 -122.369483
# 3          Queen Anne  West Queen Anne  47.638473 -122.369279
# 4          Queen Anne  West Queen Anne  47.632918 -122.372471
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     85               1                207  2016-01-02
# ...

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.palettes import d3

# %%
source = ColumnDataSource(seattle_listings[['longitude', 'latitude', 'neighbourhood_group','price']])

output_notebook()
p = figure(plot_width=1000, plot_height=600)
p.scatter(x='longitude', y='latitude', source=source)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="62880d46-67f0-4037-85ac-440337ee7c74">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d435639a-f476-4236-95e1-f08e3d69287a"></div>
# </div>
